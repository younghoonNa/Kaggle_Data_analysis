# %% [markdown]
# <a href="https://colab.research.google.com/github/younghoonNa/R/blob/main/Algorithm/R_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
array_of_a <- c(1000)
n = 1 # 이미 수열 a에 1000을 넣었기 때문, 그리고 n은 1부터 시작이므로, n = 2, a_1 = 1000
while (TRUE) {
  # n is start from 1
  n = n + 1

  array_of_a <- append(array_of_a, (-1)**(n+1) * (n-1) +  array_of_a[n-1])
  if (array_of_a[n] <= 0) { break }
  
}

print(array_of_a)
print(n+1) # 리스트의 원소는 0부터 세기 때문.
# Out:
#    [1] 1000  999 1001  998 1002  997 1003  996 1004  995 1005  994 1006  993
#   [15] 1007  992 1008  991 1009  990 1010  989 1011  988 1012  987 1013  986
#   [29] 1014  985 1015  984 1016  983 1017  982 1018  981 1019  980 1020  979
#   [43] 1021  978 1022  977 1023  976 1024  975 1025  974 1026  973 1027  972
#   [57] 1028  971 1029  970 1030  969 1031  968 1032  967 1033  966 1034  965
#   [71] 1035  964 1036  963 1037  962 1038  961 1039  960 1040  959 1041  958
#   [85] 1042  957 1043  956 1044  955 1045  954 1046  953 1047  952 1048  951
#   [99] 1049  950 1050  949 1051  948 1052  947 1053  946 1054  945 1055  944
#  [113] 1056  943 1057  942 1058  941 1059  940 1060  939 1061  938 1062  937
#  [127] 1063  936 1064  935 1065  934 1066  933 1067  932 1068  931 1069  930
#  [141] 1070  929 1071  928 1072  927 1073  926 1074  925 1075  924 1076  923
#  [155] 1077  922 1078  921 1079  920 1080  919 1081  918 1082  917 1083  916
# ...
